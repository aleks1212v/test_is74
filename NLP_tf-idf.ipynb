# %%
import pandas as pd
import numpy as np
import re

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import make_scorer, accuracy_score, f1_score, precision_score, recall_score

from sklearn.svm import SVC

# %%
data = pd.read_csv('tatarstan_message_2.csv', sep = ';')
print(data.columns)
data = data[['categories', 'description_stem']]
data.head(3)
# Out:
# Index(['Unnamed: 0', 'categories', 'description', 'description_prep',
#        'description_stem'],
#       dtype='object')
#                                 categories  \
# 0               Благоустройство территории
# 1               Благоустройство территории
# 2  Содержание и ремонт муниципальных дорог
#
#                                     description_stem
# 0  трасса нижнекамск чистополь лесополоса пгт кам...
# 1  двор дом ленинградский отсутствовать парковочн...
# 2  добрый день осуществляться уборка снег центр г...

# %% [markdown]
# LogisticRegression

# %%
#определяем модель "мешка слов"
data = data.dropna()
text_train = data['description_stem'].to_list()

vect = CountVectorizer(min_df=5).fit(text_train) #игнорировать слова, которые встречаются менее чем в min_df документах
#CountVectorizer по умолчанию сам производит токенизацию и выкидывает слова с длиной меньшей чем два.
print(vect.vocabulary_)

X_train = vect.transform(text_train)
y_train = data['categories'].to_list()
# Out:
# {'трасса': 4768, 'нижнекамск': 2481, 'чистополь': 5193, 'лесополоса': 1933, 'пгт': 2968, 'камский': 1581, 'поляна': 3311, 'проезжий': 3644, 'часть': 5164, 'опасно': 2715, 'нависать': 2237, 'накрениться': 2280, 'дерево': 949, 'снегопад': 4293, 'мочь': 2179, 'выдержать': 645, 'рухнуть': 4018, 'проходить': 3728, 'автотранспорт': 47, 'двор': 917, 'дом': 1021, 'ленинградский': 1922, 'отсутствовать': 2885, 'парковочный': 2954, 'место': 2091, 'житель': 1151, 'постоянно': 3397, 'мучиться': 2207, 'проезд': 3640, 'неоднократно': 2421, 'происходить': 3660, 'дтп': 1072, 'сторона': 4525, 'запретить': 1317, 'оставлять': 2779, 'машина': 2053, 'согласно': 4336, 'установленный': 4974, 'знак': 1410, 'предложение': 3457, 'расширение': 3922, 'авто': 23, 'фото': 5069, 'добрый': 996, 'день': 943, 'осуществляться': 2795, 'уборка': 4849, 'снег': 4292, 'центр': 5141, 'город': 824, 'гость': 839, 'воспользоваться': 561, 'платный': 3095, 'парковка': 2953, 'движение': 913, 'крайне': 1790, 'затруднить': 1363, 'вывоз': 631, 'мусор': 2198, 'территория': 4693, 'жилой': 1147, 'адрес': 61, 'ул': 4918, 'серов': 4160, 'далее': 896, 'обратиться': 2587, 'ук': 4901, 'данный': 903, 'участок': 5018, 'халитовый': 5091, 'двухсторонний': 923, 'видеть': 451, 'наличие': 2285, 'односторонний': 2670, 'убираться': 4845, 'ситуация': 4192, 'повторяться': 3143, 'год': 804, 'невозможно': 2369, 'записать': 1302, 'ребёнок': 3936, 'приём': 3591, 'госуслуга': 841, 'приложение': 3544, 'расписание': 3897, 'специалист': 4414, 'педиатр': 2970, 'просить': 3697, 'устранить': 4981, 'недостаток': 2392, 'закрасить': 1249, 'поле': 3268, 'возле': 526, 'соорудить': 4366, 'площадка': 3113, 'похожий': 3420, 'каток': 1622, 'забыть': 1179, 'почистить': 3425, 'наверное': 2233, 'подумать': 3205, 'конёк': 1752, 'ездить': 1101, 'уважаемый': 4854, 'орган': 2736, 'муниципальный': 2191, 'власть': 470, 'это': 5314, 'делать': 935, 'галочка': 748, 'проделать': 3628, 'работа': 3783, 'плохо': 3111, 'очистить': 2911, 'проезжать': 3643, 'проспект': 3699, 'победа': 3119, 'около': 2687, 'академия': 78, 'правосудие': 3443, 'мегастрой': 2063, 'именно': 1462, 'правый': 3444, 'дорога': 1039, 'автобусный': 25, 'полоса': 3298, 'также': 4627, 'заезд': 1224, 'выезд': 648, 'оба': 2533, 'направление': 2312, 'мамадышский': 2028, 'тракт': 4756, 'сузить': 4575, 'необходимо': 2418, 'хороший': 5121, 'чистить': 5189, 'убирать': 4844, 'тротуар': 4792, 'точнее': 4738, 'весь': 429, 'расположить': 3901, 'нужно': 2524, 'передвижение': 2996, 'пешеход': 3064, 'просьба': 3705, 'граффити': 853, 'стена': 4496, 'вишневский': 458, 'железный': 1127, 'решётка': 3979, 'вход': 606, 'подъезд': 3208, 'улица': 4920, 'студенческий': 4554, 'снежный': 4295, 'сезон': 4143, 'видно': 454, 'вообще': 551, 'колея': 1691, 'ужасный': 4894, 'принять': 3560, 'мера': 2083, 'трактор': 4757, 'конец': 1732, 'шакал': 5216, 'избежание': 1438, 'исход': 1531, 'сквер': 4201, 'рядом': 4033, 'почта': 3427, 'металлический': 2097, 'крышка': 1846, 'ливневка': 1947, 'куча': 1881, 'неубранный': 2459, 'школа': 5238, 'мусин': 2196, 'необходимый': 2420, 'очистка': 2912, 'пешеходный': 3066, 'дорожка': 1042, 'магазин': 2007, 'светофор': 4113, 'автомойка': 41, 'зима': 1404, 'чиститься': 5190, 'хозяин': 5112, 'сильный': 4186, 'пройти': 3663, 'столб': 4512, 'стоить': 4507, 'проводы': 3616, 'закрепить': 1250, 'играть': 1432, 'отлов': 2852, 'собака': 4309, 'нужный': 2525, 'пока': 3242, 'нибыть': 2477, 'покупать': 3261, 'далеко': 897, 'здание': 1388, 'челныгорстрой': 5171, 'сваливать': 4093, 'бетонный': 240, 'забор': 1173, 'автозаправка': 31, 'мост': 2172, 'причина': 3583, 'назвать': 2257, 'предыдущий': 3481, 'заявка': 1381, 'никакой': 2490, 'явно': 5328, 'наблюдаться': 2227, 'устранение': 4980, 'антисанитария': 115, 'дальнейший': 898, 'просто': 3701, 'вывезти': 628, 'сделать': 4138, 'пустой': 3760, 'контейнер': 1742, 'вечером': 439, 'январь': 5345, 'картина': 1607, 'регулярный': 3944, 'второй': 604, 'неделя': 2382, 'новоселье': 2500, 'частное': 5159, 'сектор': 4145, 'вдоль': 396, 'наиля' ...

# %%
#определяем метрики для скоринга
scoring = {'Accuracy': make_scorer(accuracy_score), 
           'Precision': make_scorer(precision_score, average = 'weighted'), 
           'Recall': make_scorer(recall_score, average = 'weighted'),
           'f1': make_scorer(f1_score, average = 'weighted')}

# %%
#определение наилучших параметров регуляризации (логистическая регрессия)
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10]}
grid = GridSearchCV(LogisticRegression(max_iter=10000), param_grid, cv=5)
grid.fit(X_train, y_train)
print("Наилучшее значение перекрестной проверки: {:.2f}".format(grid.best_score_))
print("Наилучшие параметры: ", grid.best_params_)
# Out:
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Наилучшее значение перекрестной проверки: 0.80
# Наилучшие параметры:  {'C': 1}

# %%
#кросс-валидация для "мешка слов" (логистическая регрессия)
scores = cross_validate(LogisticRegression(max_iter=10000, C = 1), X_train, y_train, scoring = scoring, cv=5)
print(f"Accuracy перекр проверки: {np.mean(scores['test_Accuracy'])}")
print(f"Precision перекр проверки: {np.mean(scores['test_Precision'])}")
print(f"Recall перекр проверки: {np.mean(scores['test_Recall'])}")
print(f"f1 перекр проверки: {np.mean(scores['test_f1'])}")
# Out:
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy перекр проверки: 0.8006068177761912
# Precision перекр проверки: 0.8016630162088167
# Recall перекр проверки: 0.8006068177761912
# f1 перекр проверки: 0.7960243392956132
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#определяем модель "tf-idf"
data = data.dropna()
text_train = data['description_stem'].to_list()

vect = TfidfVectorizer(min_df=5).fit(text_train) #игнорировать слова, которые встречаются менее чем в min_df документах
print(vect.vocabulary_)

X_train = vect.transform(text_train)
y_train = data['categories'].to_list()
# Out:
# {'трасса': 4768, 'нижнекамск': 2481, 'чистополь': 5193, 'лесополоса': 1933, 'пгт': 2968, 'камский': 1581, 'поляна': 3311, 'проезжий': 3644, 'часть': 5164, 'опасно': 2715, 'нависать': 2237, 'накрениться': 2280, 'дерево': 949, 'снегопад': 4293, 'мочь': 2179, 'выдержать': 645, 'рухнуть': 4018, 'проходить': 3728, 'автотранспорт': 47, 'двор': 917, 'дом': 1021, 'ленинградский': 1922, 'отсутствовать': 2885, 'парковочный': 2954, 'место': 2091, 'житель': 1151, 'постоянно': 3397, 'мучиться': 2207, 'проезд': 3640, 'неоднократно': 2421, 'происходить': 3660, 'дтп': 1072, 'сторона': 4525, 'запретить': 1317, 'оставлять': 2779, 'машина': 2053, 'согласно': 4336, 'установленный': 4974, 'знак': 1410, 'предложение': 3457, 'расширение': 3922, 'авто': 23, 'фото': 5069, 'добрый': 996, 'день': 943, 'осуществляться': 2795, 'уборка': 4849, 'снег': 4292, 'центр': 5141, 'город': 824, 'гость': 839, 'воспользоваться': 561, 'платный': 3095, 'парковка': 2953, 'движение': 913, 'крайне': 1790, 'затруднить': 1363, 'вывоз': 631, 'мусор': 2198, 'территория': 4693, 'жилой': 1147, 'адрес': 61, 'ул': 4918, 'серов': 4160, 'далее': 896, 'обратиться': 2587, 'ук': 4901, 'данный': 903, 'участок': 5018, 'халитовый': 5091, 'двухсторонний': 923, 'видеть': 451, 'наличие': 2285, 'односторонний': 2670, 'убираться': 4845, 'ситуация': 4192, 'повторяться': 3143, 'год': 804, 'невозможно': 2369, 'записать': 1302, 'ребёнок': 3936, 'приём': 3591, 'госуслуга': 841, 'приложение': 3544, 'расписание': 3897, 'специалист': 4414, 'педиатр': 2970, 'просить': 3697, 'устранить': 4981, 'недостаток': 2392, 'закрасить': 1249, 'поле': 3268, 'возле': 526, 'соорудить': 4366, 'площадка': 3113, 'похожий': 3420, 'каток': 1622, 'забыть': 1179, 'почистить': 3425, 'наверное': 2233, 'подумать': 3205, 'конёк': 1752, 'ездить': 1101, 'уважаемый': 4854, 'орган': 2736, 'муниципальный': 2191, 'власть': 470, 'это': 5314, 'делать': 935, 'галочка': 748, 'проделать': 3628, 'работа': 3783, 'плохо': 3111, 'очистить': 2911, 'проезжать': 3643, 'проспект': 3699, 'победа': 3119, 'около': 2687, 'академия': 78, 'правосудие': 3443, 'мегастрой': 2063, 'именно': 1462, 'правый': 3444, 'дорога': 1039, 'автобусный': 25, 'полоса': 3298, 'также': 4627, 'заезд': 1224, 'выезд': 648, 'оба': 2533, 'направление': 2312, 'мамадышский': 2028, 'тракт': 4756, 'сузить': 4575, 'необходимо': 2418, 'хороший': 5121, 'чистить': 5189, 'убирать': 4844, 'тротуар': 4792, 'точнее': 4738, 'весь': 429, 'расположить': 3901, 'нужно': 2524, 'передвижение': 2996, 'пешеход': 3064, 'просьба': 3705, 'граффити': 853, 'стена': 4496, 'вишневский': 458, 'железный': 1127, 'решётка': 3979, 'вход': 606, 'подъезд': 3208, 'улица': 4920, 'студенческий': 4554, 'снежный': 4295, 'сезон': 4143, 'видно': 454, 'вообще': 551, 'колея': 1691, 'ужасный': 4894, 'принять': 3560, 'мера': 2083, 'трактор': 4757, 'конец': 1732, 'шакал': 5216, 'избежание': 1438, 'исход': 1531, 'сквер': 4201, 'рядом': 4033, 'почта': 3427, 'металлический': 2097, 'крышка': 1846, 'ливневка': 1947, 'куча': 1881, 'неубранный': 2459, 'школа': 5238, 'мусин': 2196, 'необходимый': 2420, 'очистка': 2912, 'пешеходный': 3066, 'дорожка': 1042, 'магазин': 2007, 'светофор': 4113, 'автомойка': 41, 'зима': 1404, 'чиститься': 5190, 'хозяин': 5112, 'сильный': 4186, 'пройти': 3663, 'столб': 4512, 'стоить': 4507, 'проводы': 3616, 'закрепить': 1250, 'играть': 1432, 'отлов': 2852, 'собака': 4309, 'нужный': 2525, 'пока': 3242, 'нибыть': 2477, 'покупать': 3261, 'далеко': 897, 'здание': 1388, 'челныгорстрой': 5171, 'сваливать': 4093, 'бетонный': 240, 'забор': 1173, 'автозаправка': 31, 'мост': 2172, 'причина': 3583, 'назвать': 2257, 'предыдущий': 3481, 'заявка': 1381, 'никакой': 2490, 'явно': 5328, 'наблюдаться': 2227, 'устранение': 4980, 'антисанитария': 115, 'дальнейший': 898, 'просто': 3701, 'вывезти': 628, 'сделать': 4138, 'пустой': 3760, 'контейнер': 1742, 'вечером': 439, 'январь': 5345, 'картина': 1607, 'регулярный': 3944, 'второй': 604, 'неделя': 2382, 'новоселье': 2500, 'частное': 5159, 'сектор': 4145, 'вдоль': 396, 'наиля' ...

# %%
#определение наилучших параметров регуляризации (логистическая регрессия)
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10]}
grid = GridSearchCV(LogisticRegression(max_iter=10000), param_grid, cv=5)
grid.fit(X_train, y_train)
print("Наилучшее значение перекрестной проверки: {:.2f}".format(grid.best_score_))
print("Наилучшие параметры: ", grid.best_params_)
# Out:
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Наилучшее значение перекрестной проверки: 0.81
# Наилучшие параметры:  {'C': 10}

# %%
#кросс-валидация для "tf-idf" (логистическая регрессия)
scores = cross_validate(LogisticRegression(max_iter=10000, C = 10), X_train, y_train, scoring = scoring, cv=5)
print(f"Accuracy перекр проверки: {np.mean(scores['test_Accuracy'])}")
print(f"Precision перекр проверки: {np.mean(scores['test_Precision'])}")
print(f"Recall перекр проверки: {np.mean(scores['test_Recall'])}")
print(f"f1 перекр проверки: {np.mean(scores['test_f1'])}")
# Out:
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy перекр проверки: 0.8053185793325003
# Precision перекр проверки: 0.8066960117864305
# Recall перекр проверки: 0.8053185793325003
# f1 перекр проверки: 0.8002917471947502
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# SVM

# %%
data = data.dropna()
text_train = data['description_stem'].to_list()
data = data.dropna()
text_train = data['description_stem'].to_list()

vect = TfidfVectorizer(min_df=5).fit(text_train) #игнорировать слова, которые встречаются менее чем в min_df документах

X_train = vect.transform(text_train)
y_train = data['categories'].to_list()
print(X_train)
# Out:
#   (0, 5193)	0.2419649834794235
#   (0, 5164)	0.13253535196969443
#   (0, 4768)	0.21706794930369874
#   (0, 4293)	0.22015866481197535
#   (0, 4018)	0.277977201952757
#   (0, 3728)	0.17996058079023988
#   (0, 3644)	0.142418126814633
#   (0, 3311)	0.2756026837404905
#   (0, 2968)	0.2756026837404905
#   (0, 2715)	0.16957862872623766
#   (0, 2481)	0.2226895588006144
#   (0, 2280)	0.2675502344612076
#   (0, 2237)	0.2713241599260953
#   (0, 2179)	0.1343219024974561
#   (0, 1933)	0.28975959407783153
#   (0, 1581)	0.26581784862117136
#   (0, 949)	0.14064050082168006
#   (0, 645)	0.28975959407783153
#   (0, 47)	0.21562764691728073
#   (1, 5069)	0.1532994855817944
#   (1, 4974)	0.18826985671331037
#   (1, 4525)	0.11931791123495233
#   (1, 4336)	0.18736883835772375
#   (1, 3922)	0.2366874271524845
#   (1, 3660)	0.19089966618622384
#   :	:
#   (28014, 940)	0.01758179887025656
#   (28014, 917)	0.019628077414272714
#   (28014, 913)	0.03810344352723242
#   (28014, 905)	0.02678995289458987
#   (28014, 903)	0.01154264848802535
#   (28014, 835)	0.016112784794192724
#   (28014, 826)	0.20545623862727955
#   (28014, 804)	0.010176495698944231
#   (28014, 779)	0.01966399111685349
#   (28014, 751)	0.03464299594100399
#   (28014, 750)	0.04614509458015043
#   (28014, 565)	0.01173205379223571
#   (28014, 551)	0.01391398412492256
#   (28014, 479)	0.032509077805393624
#   (28014, 429)	0.019661401120487566
#   (28014, 428)	0.018011097032216965
#   (28014, 401)	0.019732964939626348
#   (28014, 396)	0.023320324559182946
#   (28014, 387)	0.05899197335056047
#   (28014, 264)	0.15878092757139464
#   (28014, 165)	0.024039282863237834
#   (28014, 77)	0.03588046656476087
#   (28014, 66)	0.16023097500589292
#   (28014, 58)	0.09116246379054109
#   (28014, 38)	0.033599980362891434

# %%
#определение наилучших параметров регуляризации (SVM)
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10]}
grid = GridSearchCV(SVC(probability=False, kernel='rbf'), param_grid, cv=5)
grid.fit(X_train, y_train)
print("Наилучшее значение перекрестной проверки: {:.2f}".format(grid.best_score_))
print("Наилучшие параметры: ", grid.best_params_)
# Out:
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Наилучшее значение перекрестной проверки: 0.81
# Наилучшие параметры:  {'C': 10}

# %%
#кросс-валидация для "tf-idf" (SVM)
scores = cross_validate(SVC(probability=False, kernel='rbf', C = 10), X_train, y_train, scoring = scoring, cv=3)
print(f"Accuracy перекр проверки: {np.mean(scores['test_Accuracy'])}")
print(f"Precision перекр проверки: {np.mean(scores['test_Precision'])}")
print(f"Recall перекр проверки: {np.mean(scores['test_Recall'])}")
print(f"f1 перекр проверки: {np.mean(scores['test_f1'])}")
# Out:
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# C:\Anaconda\envs\python_37\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy перекр проверки: 0.801963507408488
# Precision перекр проверки: 0.8020048804601069
# Recall перекр проверки: 0.801963507408488
# f1 перекр проверки: 0.7935485191387023
